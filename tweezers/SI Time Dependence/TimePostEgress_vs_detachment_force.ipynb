# %%
# import the packages needed for plotting
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mc
import colorsys
import  matplotlib.axes as ax

# %%
# import the packages needed for plotting
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mc
import colorsys
import  matplotlib.axes as ax

# %%
colors_light = {
    'NF54': '#829AA3',
    'Heparin 50':'#829AA3',
    
    '3D7':'#B9BDC5',
    '3D7 (viola)': '#B9BDC5',

    'KOP230P': '#91b1be',
    'KOPfs25': '#9fc9d9',

    'KOEBA140': '#DAEBC6',
    'KOEBA181': '#84B06D',
    'KOEBA175': '#C1E2D4',
    'KOEBA175+Anti-GYPA':'#A5D0D4',
    'KORH1': '#F9DA9A',
    'KORH4': '#F3A59B',
    'KORh2a': '#F7CAA1',
    'KORH2a': '#F7CAA1',

    

    'Barseq': '#BEBFBC',

    'cKOMSP1':'#B9BDC5',
    'cKOMSP1 DMSO':'#B9BDC5',
    'cKOMSP1 Rap':'#FFE3B8',

    'Neuraminidase':'#D6EE96',
    
    'Anti-CD55':'#97B6DA',
    'Anti-GYPA':'#B6E2DF',
    'R1':'#F1AAD1',
    'Anti-GYPC':'#93E1DB',
    'Anti-CR1 ab25':'#DEAC7F',
    'Anti-CR1 ABIN':'#DEAC7F',

    'Anti-Basigin':'#C6C5D3',
   
    
    'cKOGAP45': '#B9BDC5',
    'cKOGAP45 DMSO': '#B9BDC5',
    'cKOGAP45 Rap': '#E5486C',
    
    'cKOAMA1':'#B9BDC5',
    'cKOAMA1 DMSO':'#B9BDC5',
    'cKOAMA1 Rap':'#EBD1D9',
    
 
}

colors_dark = {
    'NF54': '#043546',
    'Heparin 50':'#818897',

    '3D7':'#818897',
    '3D7 (viola)': '#818897',

    'KOP230P': '#406a7d',
    'KOPfs25': '#78a3b9',

    'KOEBA140': '#9ECA69',
    'KOEBA181': '#486737',
    'KOEBA175': '#6AB997',
    'KOEBA175+Anti-GYPA':'#04A0AF',
    'KORH1': '#F1AF23',
    'KORH4': '#E8513E',
    'KORh2a': '#ED8626',
    'KORH2a': '#ED8626',


    'Barseq': '#BEBFBC',

    'cKOMSP1':'#FFD086',
    'cKOMSP1 DMSO':'#FFD086',
    'cKOMSP1 Rap':'#FFD086',

    'Neuraminidase':'#ABDC29',
    
    'Anti-CD55':'#97B6DA',
    'Anti-GYPA':'#91D4CF',
    'R1':'#E459A5',
    'Anti-GYPC':'#35BEB4',
    'Anti-CR1 ab25':'#C6545E',
    'Anti-CR1 ABIN':'#C6545E',

    'Anti-Basigin':'#7E7C9C',
   
    
  
    'cKOGAP45': '#81132C',
    'cKOGAP45 DMSO': '#81132C',
    'cKOGAP45 Rap': '#81132C',

    'cKOAMA1':'#CC889D',
    'cKOAMA1 DMSO':'#CC889D',
    'cKOAMA1 Rap':'#CC889D',
}

# %%
filename = 'Comparision of time post egress and detachment force.xlsx'

df_egresstime_all_raw = pd.read_excel(
    filename, 
    header=0,
   # usecols='A:CH',
   # userows='1:12',
    index_col=0,
   # nrows=ROW_COUNT,
)
df_egresstime_all_raw.index = df_egresstime_all_raw.index.str.strip() # remove whitespace

#df_egresstime_raw ["strain"] = df_egresstime_raw.index
#df_egresstime_raw['Strain'] = df_egresstime_raw['strain'].str.split(" ").str[0]

print(df_egresstime_all_raw.columns)

df_egresstime_all_raw # display dataframe
# Out:
# Index(['Strain', 'treatment', 'Time after egress (sec)  ', 'Force (pN)'], dtype='object')
#                 Strain treatment  Time after egress (sec)    Force (pN)
# Number
# EEJR0058aI.x      NF54       NaN                      59.76   11.331558
# EEJR0058aII       NF54       NaN                      95.77   20.180020
# EEJR0001c        NF54        NaN                      34.97    2.047192
# EEJR0001h        NF54        NaN                      30.83    3.810268
# EEJR0001j        NF54        NaN                      33.86   12.115796
# ...                ...       ...                        ...         ...
# EEJR0150hIII  cKOGAP45     DMSO                       55.01   49.679434
# EEJR0150hIV   cKOGAP45     DMSO                       74.29   31.015348
# EEJR0150hV    cKOGAP45     DMSO                       90.48   25.671632
# EEJR0150iI    cKOGAP45     DMSO                       57.91   38.861620
# EEJR0150iII   cKOGAP45     DMSO                      170.85   60.526438
#
# [293 rows x 4 columns]

# %%
conditions_to_plot = '3D7'

df_egresstime_raw = df_egresstime_all_raw[df_egresstime_all_raw['Strain'] == conditions_to_plot]

print(df_egresstime_raw.columns)

df_egresstime_raw # display dataframe
# Out:
# Index(['Strain', 'treatment', 'Time after egress (sec)  ', 'Force (pN)'], dtype='object')
#              Strain treatment  Time after egress (sec)    Force (pN)
# Number
# EEJR0027aI      3D7       NaN                      27.72   72.634450
# EEJR0027aII     3D7       NaN                      80.47   42.210686
# EEJR0027cI      3D7       NaN                      16.78   35.448336
# EEJR0027cII     3D7       NaN                      41.41   56.762874
# EEJR0027cIII    3D7       NaN                      90.87   23.243024
# EEJR0027e       3D7       NaN                      95.95   25.912936
# EEJR0028a.1     3D7       NaN                      78.49   45.119956
# EEJR0028bI      3D7       NaN                     137.20   22.624196
# EEJR0028bII     3D7       NaN                     168.96   27.063022
# EEJR0028cI      3D7       NaN                      35.79   44.061332
# EEJR0028cII     3D7       NaN                      82.17   31.231354
# EEJR0028cIII    3D7       NaN                     109.83   48.017550
# EEJR0028cIII    3D7       NaN                     150.10   10.516184
# EEJR0028dI      3D7       NaN                      25.19   52.814440
# EEJR0028dII     3D7       NaN                      47.13   46.589186
# EEJR0028dIII    3D7       NaN                     111.21   40.967192
# EEJR0028dIV     3D7       NaN                     132.35   41.496504
# EEJR0028dV      3D7       NaN                     146.20   28.553658
# EEJR0028dVI     3D7       NaN                     158.74   40.208252
# EEJR0028dVII    3D7       NaN                     189.28   32.173218
# EEJR0028e       3D7       NaN                      71.51   21.094640
# EEJR0028e       3D7       NaN                      84.83   24.558520
# EEJR0028e       3D7       NaN                     175.30   12.968144

# %%
plt.figure()
plt.gcf().set_size_inches(12,9)
plt.gcf().set_dpi(300)

sns.set_theme(#context='notebook', 
            #style='ticks', 
            style='darkgrid', 
            font='arial', 
            font_scale=3.5) 
            #   color_codes=True, 
            #   rc=None)
sns.set_style(rc = {'axes.facecolor': '#F5F5F9'})
#sns.set_style(rc = {'axes.facecolor': '#FBF9F6'})


### calculate the coefficent of variance 

x_column = 'Time after egress (sec)  ' 
y_column = 'Force (pN)' 

# Extract data from DataFrame columns
x_data = df_egresstime_raw[x_column].values
y_data = df_egresstime_raw[y_column].values

# Calculate correlation coefficient
correlation_matrix = np.corrcoef(x_data, y_data)
correlation_coefficient = correlation_matrix[0, 1]

 # Calculate R-squared
r_squared = correlation_matrix[0, 1] ** 2


#legend_label = f"Correlation coefficient: {correlation_coefficient:.3f}\nR-squared = {r_squared:.3f}"
#legend_label = f"R-squared = {r_squared:.3f}"
legend_label = f"Correlation coefficient: {correlation_coefficient:.3f}\nR-squared = {r_squared:.3f} \nn={len(df_egresstime_raw)}"

print(f"Correlation Coefficient: {correlation_coefficient}")

#label = f'Fit: y = {slope:.2f} * log10(x) + {intercept:.2f}\nR-squared = {r_squared:.2f}\nEfficiency = {efficiency:.0f}%'




sns.regplot(
    data=df_egresstime_raw,
    x="Time after egress (sec)  ", 
    y="Force (pN)",
    scatter=False,
    line_kws={'color': '.7'},
    fit_reg=True,
    ci=None,
    )


sns.scatterplot(
    data=df_egresstime_raw, 
    x="Time after egress (sec)  ", 
    y="Force (pN)", 
    # #NF54
    # edgecolor='#043546',
    # facecolor='#829AA3',
    # #3D7
    # edgecolor='#818897',
    # facecolor='#B9BDC5',
    #other
    # edgecolor='darkblue',
    # facecolor='darkblue',
    hue=df_egresstime_raw.Strain,
    palette=colors_light,
    edgecolor=[colors_dark.get(s, 'r') for s in df_egresstime_raw.Strain],
    s=100,
    marker='o',
    linewidth=2,
    #label=legend_label,
    legend=False,
)



plt.xlim((0,220))
plt.ylim((0,90))
#plt.legend()
plt.title(conditions_to_plot)
#sns.move_legend(plt.gca(), "upper left", bbox_to_anchor=(1, 1))

label_info = f"Correlation coefficient: {correlation_coefficient:.3f}\nR-squared = {r_squared:.3f} \nn={len(df_egresstime_raw)}"
plt.annotate(label_info, xy=(0.05, -0.5), xycoords='axes fraction', fontsize=40)

plt.rcParams['svg.fonttype'] = 'none'
plt.savefig(f'Graphs/SupFig1d_egress time vs force_{conditions_to_plot}.svg', bbox_inches='tight')
# Out:
# Correlation Coefficient: -0.5876170635131005
