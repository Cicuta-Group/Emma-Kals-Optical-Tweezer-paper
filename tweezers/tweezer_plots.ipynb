# NF54 2                              NaN        NaN  ...       NaN      NaN
# NF54 3                              NaN        NaN  ...       NaN      NaN
# NF54 5                              NaN        NaN  ...       NaN      NaN
# NF54 87                       13.516916        NaN  ...       NaN      NaN
# NF54 125                      34.998810  14.217476  ...       NaN      NaN
# NF54 128                            NaN        NaN  ...       NaN      NaN
# NF54 132                      19.496974  15.009498  ...       NaN      NaN
# cKOMSP1 DMSO (normal egress)  48.270530  61.989830  ...       NaN      NaN
# cKOMSP1 Rap (clumpy egress)   30.042348   8.566292  ...       NaN      NaN
# cKOAMA1 x                      7.353934  32.786208  ...       NaN      NaN
# cKOAMA1 y                     24.110940  18.539542  ...       NaN      NaN
# cKOAMA1 mean                  15.732437  25.662875  ...       NaN      NaN
# cKOAMA1 single                12.117742  30.491874  ...       NaN      NaN
# cKOMSP1 x                      5.084898  35.882294  ...       NaN      NaN
# cKOMSP1 y                     13.007064  47.124336  ...       NaN      NaN
# cKOMSP1 mean                   9.045981  41.503315  ...       NaN      NaN
# cKOMSP1 single                16.920470  22.674792  ...       NaN      NaN
# cKOGAP45 x                    25.190970  23.229402  ...       NaN      NaN
# cKOGAP45 y                    26.302136  28.170296  ...       NaN      NaN
# cKOGAP45 mean                 25.746553  25.699849  ...       NaN      NaN
# cKOGAP45 single               19.876444  36.956486  ...       NaN      NaN
# NF54 x                        21.191940   1.982974  ...       NaN      NaN
# NF54 y                        10.858680  16.184882  ...       NaN      NaN
# NF54 mean                     16.025310   9.083928  ...       NaN      NaN
# NF54 single                   45.653160  19.444432  ...       NaN      NaN
#
#                                      92        93         94         95  \
# NF54                                NaN       NaN        NaN        NaN
# NF54 old                            NaN       NaN        NaN        NaN
# NF54 new                            NaN       NaN        NaN        NaN
# 3D7 (viola)                         NaN       NaN        NaN        NaN
# 3D7                                 NaN       NaN        NaN        NaN
# Glut                                NaN       NaN        NaN        NaN
# Anti-Basigin                        NaN       NaN        NaN        NaN
# Anti-CD55                           NaN       NaN        NaN        NaN
# Anti-GYPA                           NaN       NaN        NaN        NaN
# Heparin 50                          NaN       NaN        NaN        NaN
# R1                                  NaN       NaN        NaN        NaN
# Neuraminidase                       NaN       NaN        NaN        NaN
# Anti-GYPC                           NaN       NaN        NaN        NaN
# Anti-CR1 ab25                       NaN       NaN        NaN        NaN
# Anti-CR1 ABIN                       NaN       NaN        NaN        NaN
# KOEBA140                            NaN       NaN        NaN        NaN
# KOEBA181                            NaN       NaN        NaN        NaN
# KORH4                               NaN       NaN        NaN        NaN
# KOEBA175                            NaN       NaN        NaN        NaN
# KORH1                               NaN       NaN        NaN        NaN
# KORH2a                              NaN       NaN        NaN        NaN
# cKOAMA1 DMSO                        NaN       NaN        NaN        NaN
# cKOAMA1 Rap                         NaN       NaN        NaN        NaN
# KOP230P                             NaN       NaN        NaN        NaN
# KOPfs25                             NaN       NaN        NaN        NaN
# KOEBA175+Anti-GYPA                  NaN       NaN        NaN        NaN
# cKOMSP1 DMSO                        NaN       NaN        NaN        NaN
# cKOMSP1 Rap                         NaN       NaN        NaN        NaN
# cKOGAP45 DMSO                 83.810328  58.75947  49.679434  31.015348
# NF54 5                              NaN       NaN        NaN NaN
# NF54 87                             NaN       NaN        NaN NaN
# NF54 125                            NaN       NaN        NaN NaN
# NF54 128                            NaN       NaN        NaN NaN
# NF54 132                            NaN       NaN        NaN NaN
# cKOMSP1 DMSO (normal egress)        NaN       NaN        NaN NaN
# cKOMSP1 Rap (clumpy egress)         NaN       NaN        NaN NaN
# cKOAMA1 x                           NaN       NaN        NaN NaN
# cKOAMA1 y                           NaN       NaN        NaN NaN
# cKOAMA1 mean                        NaN       NaN        NaN NaN
# cKOAMA1 single                      NaN       NaN        NaN NaN
# cKOMSP1 x                           NaN       NaN        NaN NaN
# cKOMSP1 y                           NaN       NaN        NaN NaN
# cKOMSP1 mean                        NaN       NaN        NaN NaN
# cKOMSP1 single                      NaN       NaN        NaN NaN
# cKOGAP45 x                          NaN       NaN        NaN NaN
# cKOGAP45 y                          NaN       NaN        NaN NaN
# cKOGAP45 mean                       NaN       NaN        NaN NaN
# cKOGAP45 single                     NaN       NaN        NaN NaN
# NF54 x                              NaN       NaN        NaN NaN
# NF54 y                              NaN       NaN        NaN NaN
# NF54 mean                           NaN       NaN        NaN NaN
# NF54 single                         NaN       NaN        NaN NaN
#
# [56 rows x 99 columns]

# %%
df_freq_raw = pd.read_excel(
    filename, 
    header=0,
    usecols='A,CY:DP',
    index_col=0,
    nrows=ROW_COUNT,
).dropna(axis=1, how='all').dropna(axis=0, how='all')

df_freq_raw.index = df_freq_raw.index.str.strip() # remove whitespace

df_freq_raw # display dataframe
# Out:
#                                  n      mean        SEM  \
# NF54                          85.0  24.177516  1.540224
# NF54 old                      28.0  28.610370  3.043996
# NF54 new                      53.0  22.294331  1.811081
# 3D7 (viola)                   21.0  42.536810  3.432459
# 3D7                           23.0  35.924768  3.054521
# Glut                          21.0  28.143145  5.434934
# Anti-Basigin                  31.0  30.847866  3.072590
# Anti-CD55                      9.0  20.961663  4.882831
# Anti-GYPA                     11.0  14.209692  2.286176
# Heparin 50                     4.0  30.443224  3.598563
# R1                            41.0  32.962914  2.853341
# Neuraminidase                  4.0  13.334478  4.850348
# Anti-GYPC                     21.0  19.293107  2.655903
# Anti-CR1 ab25                 17.0  25.857074  3.728186
# Anti-CR1 ABIN                 13.0  28.952738  3.935685
# KOEBA140                      17.0  23.496233  3.681585
# KOEBA181                      26.0  22.632354  2.571547
# KORH4                         23.0  19.027142  2.462294
# KOEBA175                      51.0  31.120203  1.778438
# KORH1                         38.0  23.387028  2.200873
# KORH2a                        27.0  27.331282  2.810635
# cKOAMA1 DMSO                  73.0  26.726844  1.888694
# cKOAMA1 Rap                   42.0  28.559403  2.395913
# KOP230P                       50.0  26.354406  1.623549
# KOPfs25                       35.0  25.905319  1.953448
# KOEBA175+Anti-GYPA            15.0  16.175801  2.005424
# cKOMSP1 DMSO                  55.0  29.467393  2.203240
# cKOMSP1 Rap                   57.0  25.191721  1.914083
# cKOGAP45 DMSO                 98.0  30.402259  1.495680
# cKOGAP45 Rap                  39.0  31.034658  2.697031
# NF54 1                         NaN  23.679171  6.974120
# NF54 2                         NaN  33.738532  5.794519
# NF54 3                         NaN  35.523257  8.329853
# NF54 5                         NaN  34.151976  5.610019
# NF54 87                        NaN  24.715714  5.858450
# NF54 125                       NaN  22.752956  3.152441
# NF54 128                       NaN  15.850657  8.481337
# NF54 132                       NaN  22.240000  2.349186
# cKOMSP1 DMSO (normal egress)  50.0  29.935162  2.402068
# cKOMSP1 Rap (clumpy egress)   47.0  25.397287  2.157912
#
#                              Normal Gausian distributed  sig diff to NF54   \
# NF54                                                Yes                NA
# NF54 old                                             NaN               NaN
# NF54 new                                             NaN               NaN
# 3D7 (viola)                                          NaN               NaN
# 3D7                                                 Yes        No = 0.0993
# Glut                                                 No        No = 0.4609
# Anti-Basigin                                        Yes        No = 0.6077
# Anti-CD55                                           Yes        No = 0.2118
# Anti-GYPA                                            No       Yes = 0.0067
# Heparin 50                                          Yes        No = 0.8258
# R1                                                   No        No = 0.5054
# Neuraminidase                                        No        No = 0.0563
# Anti-GYPC                                           Yes       Yes = 0.0316
# Anti-CR1 ab25                                       Yes        No = 0.5749
# Anti-CR1 ABIN                                        NaN               NaN
# KOEBA140                                             No        No = 0.2763
# KOEBA181                                             No        No = 0.2426
# KORH4                                               Yes       Yes = 0.0215
# KOEBA175                                            yes       No = 0.7727
# KORH1                                               Yes        No = 0.1583
# KORH2a                                               No       No = 0.1014
# cKOAMA1 DMSO                                         NaN               NaN
# cKOAMA1 Rap                                          NaN               NaN
# KOP230P                                              NaN               NaN
# KOPfs25                                              NaN               NaN
# KOEBA175+Anti-GYPA                                   NaN               NaN
# cKOMSP1 DMSO                                         NaN               NaN
# cKOMSP1 Rap                                          NaN               NaN
# cKOGAP45 DMSO                                        NaN               NaN
# cKOGAP45 Rap                                         NaN               NaN
# NF54 1                                               NaN               NaN
# NF54 2                                               NaN               NaN
# NF54 3                                               NaN               NaN
# NF54 5                                               NaN               NaN
# NF54 87                                              NaN               NaN
# NF54 125                                             NaN               NaN
# NF54 128                                             NaN               NaN
# NF54 132                                             NaN               NaN
# cKOMSP1 DMSO (normal egress)                         NaN               NaN
# cKOMSP1 Rap (clumpy egress)                          NaN               NaN
#
#                                              Unnamed: 107  \
# NF54                                                  NaN
# NF54 old                                              NaN
# NF54 new                                              NaN
# 3D7 (viola)                                           NaN
# 3D7                                                   NaN
# Glut                                                  NaN
# Anti-Basigin                                          NaN
# Anti-CD55                                             NaN
# Anti-GYPA                                             NaN
# Heparin 50                                            NaN
# R1                                                    NaN
# Neuraminidase                                         NaN
# Anti-GYPC                                             NaN
# Anti-CR1 ab25                                         NaN
# Anti-CR1 ABIN                                         NaN
# KOEBA140                                              NaN
# KOEBA181                                              NaN
# KORH4                                                 NaN
# KOEBA175                      sig diff GYPA p = 0.0002334
# KORH1                                                 NaN
# KORH2a                                                NaN
# cKOAMA1 DMSO                                          NaN
# cKOAMA1 Rap                                           NaN
# KOP230P                                               NaN
# KOPfs25                                               NaN
# KOEBA175+Anti-GYPA                                    NaN
# cKOMSP1 DMSO                                          NaN
# cKOMSP1 Rap                                           NaN
# cKOGAP45 DMSO                                         NaN
# cKOGAP45 Rap                                          NaN
# NF54 1                                                NaN
# NF54 2                                                NaN
# NF54 3                                                NaN
# NF54 5                                                NaN
# 3D7                                             9.209475
# Glut                                                 NaN
# Anti-Basigin                                    3.242236
# Anti-CD55                                       2.662873
# Anti-GYPA                                       2.264832
# Heparin 50                                      4.843221
# R1                                              3.497168
# Neuraminidase                                   0.509649
# Anti-GYPC                                       4.791089
# Anti-CR1 ab25                                   6.949641
# Anti-CR1 ABIN                                   5.747989
# KOEBA140                                        3.811058
# KOEBA181                                        2.370122
# KORH4                                           2.522163
# KOEBA175                                        2.332755
# KORH1                                           2.435913
# KORH2a                                          1.839240
# cKOAMA1 DMSO                                    3.000802
# cKOAMA1 Rap                                     4.709146
# KOP230P                                         1.800572
# KOPfs25                                         2.996577
# KOEBA175+Anti-GYPA                              1.321041
# cKOMSP1 DMSO                                    3.473007
# cKOMSP1 Rap                                     3.381717
# cKOGAP45 DMSO                                   2.633418
# cKOGAP45 Rap                                    1.501254
# NF54 1                                          8.714361
# NF54 2                                          8.350281
# NF54 3                                         16.666667
# NF54 5                                          5.411366
# NF54 87                                         3.609475
# NF54 125                                        6.707326
# NF54 128                                        1.584170
# NF54 132                                        5.997090
# cKOMSP1 DMSO (normal egress)                    3.990000
# cKOMSP1 Rap (clumpy egress)                     3.810000
#
#                               Invasion efficeny (Flow)      SEM.1
# NF54                                         100.000000       NaN
# NF54 old                                            NaN       NaN
# NF54 new                                            NaN       NaN
# 3D7 (viola)                                         NaN       NaN
# 3D7                                                 NaN       NaN
# Glut                                                NaN       NaN
# Anti-Basigin                                  22.970624  3.636610
# Anti-CD55                                     82.120807  6.103501
# Anti-GYPA                                     55.541310  7.381862
# Heparin 50                                    24.710715  9.705865
# R1                                            29.218108  1.711476
# Neuraminidase                                 56.962715  3.164537
# Anti-GYPC                                     88.975955  7.205445
# Anti-CR1 ab25                                       NaN       NaN
# Anti-CR1 ABIN                                       NaN       NaN
# KOEBA140                                            NaN       NaN
# KOEBA181                                            NaN       NaN
# KORH4                                               NaN       NaN
# KOEBA175                                            NaN       NaN
# KORH1                                               NaN       NaN
# KORH2a                                              NaN       NaN
# cKOAMA1 DMSO                                        NaN       NaN
# cKOAMA1 Rap                                         NaN       NaN
# KOP230P                                             NaN       NaN
# KOPfs25                                             NaN       NaN
# KOEBA175+Anti-GYPA                                  NaN       NaN
# cKOMSP1 DMSO                                        NaN       NaN
# cKOMSP1 Rap                                         NaN       NaN
# cKOGAP45 DMSO                                       NaN       NaN
# cKOGAP45 Rap                                        NaN       NaN
# NF54 1                                              NaN       NaN
# NF54 2                                              NaN       NaN
# NF54 3                                              NaN       NaN
# NF54 5                                              NaN       NaN
# NF54 87                                             NaN       NaN
# NF54 125                                            NaN       NaN
# NF54 128                                            NaN       NaN
# NF54 132                                            NaN       NaN
# cKOMSP1 DMSO (normal egress)                        NaN       NaN
# cKOMSP1 Rap (clumpy egress)                         NaN       NaN

# %%
conditions_to_plot = [
    ## All
    # 'NF54',
    # '3D7',
    # 'cKOMSP1 DMSO',
    # 'cKOMSP1 Rap',
    # 'Neuraminidase',
    # 'Anti-GYPA',
    # 'Anti-GYPC',
    # 'KOP230P',
    # 'KOPfs25',
    # 'KOEBA140',
   # 'KOEBA175',
    # 'KOEBA181',
    # 'KORH1',
    # 'KORH2a',
    # 'KORH4',
   # 'KOEBA175+Anti-GYPA',
    # 'Anti-Basigin', 
    # 'R1',
    # 'cKOAMA1 DMSO', 
    # 'cKOAMA1 Rap',
    # 'cKOGAP45 DMSO',
    # 'cKOGAP45 Rap',
    #'Heparin 50',	


    # '3D7 (viola)',
    #'Anti-CD55',
    # 'Anti-CR1 ab25',
    # 'Anti-CR1 ABIN',
    # 'NF54 old',
    # 'NF54 new',
    # 'Glut',

## Figure 1c/d - wild-type
# 'NF54',
# '3D7',

## Figure 1f/g
    'cKOMSP1 DMSO',
    'cKOMSP1 Rap',
    #  'NF54',
    #  'Neuraminidase',
    # 'Anti-GYPA',
    # 'Anti-GYPC',
    # 'Anti-CR1 ab25',
    # 'Anti-Basigin', 
    # 'R1',
    #  'cKOGAP45 DMSO',
    # 'cKOGAP45 Rap',  
    # 'cKOAMA1 DMSO', 
    #  'cKOAMA1 Rap',

    # 'cKOMSP1 DMSO (normal egress)',
    # 'cKOMSP1 Rap (clumpy egress)',

    ## KO lines - Figure 4  
    # 'NF54',
    # 'KOP230P',
    # 'KOPfs25',
    # 'KOEBA140',
    # 'KOEBA175',
    # 'KOEBA181',
    # 'KORH1',
    # 'KORH2a',
    # 'KORH4',
    # 'KOEBA175+Anti-GYPA',

    ## EBA175 
    # 'NF54',
    # 'Anti-GYPA',
    # 'KOEBA175',
    # 'KOEBA175+Anti-GYPA',
    
    # 'NF54',
    # 'R1',
    # '3D7',
    # 'cKOAMA1 DMSO',
    # 'cKOAMA1 Rap',
    
    # 'NF54 1',
    # 'NF54 2',
    # 'NF54 3',
    # 'NF54 5',
    # 'NF54 87',
    # 'NF54 125',
    # 'NF54 128',
    # 'NF54 132',

    # 'cKOMSP1 x', 
    # 'cKOMSP1 y',
    # 'cKOMSP1 mean',
    # 'cKOMSP1 single',

    # 'cKOGAP45 x', 
    # 'cKOGAP45 y',
    # 'cKOGAP45 mean',
    # 'cKOGAP45 single',

    # 'cKOAMA1 x', 
    # 'cKOAMA1 y',
    # 'cKOAMA1 mean',
    # 'cKOAMA1 single',

    # 'NF54 x', 
    # 'NF54 y',
    # 'NF54 mean',
    # 'NF54 single',




## ordered by invasion 
    # 'cKOMSP1 DMSO',
    # 'cKOMSP1 Rap',
    # 'NF54',
    # 'Neuraminidase',
    # 'Anti-GYPA',
    # 'Anti-GYPC',
    # 'KOP230P',
    # 'KOPfs25',
    # 'KOEBA140',
    # 'KOEBA175',
    # 'KOEBA181',
    # 'KORH1',
    # 'KORH2a',
    # 'KORH4',
    # 'Anti-Basigin', 
    # 'cKOGAP45 DMSO',
    # 'cKOGAP45 Rap',
    # 'R1',
    # 'cKOAMA1 DMSO', 
    # 'cKOAMA1 Rap',



]




colors_light = {
    'NF54': '#829AA3',
    'Heparin 50':'#829AA3',
    
    '3D7':'#B9BDC5',
    '3D7 (viola)': '#B9BDC5',

    'KOP230P': '#91b1be',
    'KOPfs25': '#9fc9d9',

    'KOEBA140': '#DAEBC6',
    'KOEBA181': '#84B06D',
    'KOEBA175': '#C1E2D4',
    'KOEBA175+Anti-GYPA':'#A5D0D4',
    'KORH1': '#F9DA9A',
    'KORH4': '#F3A59B',
    'KORh2a': '#F7CAA1',
    'KORH2a': '#F7CAA1',

    

    'Barseq': '#BEBFBC',

    'cKOMSP1 DMSO':'#B9BDC5',
    'cKOMSP1 Rap':'#FFE3B8',

    'cKOMSP1 DMSO (normal egress)':'#B9BDC5',
    'cKOMSP1 Rap (clumpy egress)':'#FFE3B8',

    'Neuraminidase':'#D6EE96',
    
    'Anti-CD55':'#97B6DA',
    'Anti-GYPA':'#B6E2DF',
    'R1':'#F1AAD1',
    'Anti-GYPC':'#93E1DB',
    'Anti-CR1 ab25':'#DEAC7F',
    'Anti-CR1 ABIN':'#DEAC7F',

    'Anti-Basigin':'#C6C5D3',
   
    
  
    'cKOGAP45 DMSO': '#B9BDC5',
    'cKOGAP45 Rap': '#E5486C',

    'cKOAMA1 DMSO':'#B9BDC5',
    'cKOAMA1 Rap':'#EBD1D9',

    'NF54 x': '#829AA3',
    'NF54 y': '#829AA3',
    'NF54 mean': '#829AA3',
    'NF54 single': '#829AA3',

    'cKOMSP1 x': '#B9BDC5',
    'cKOMSP1 y': '#B9BDC5',
    'cKOMSP1 mean': '#B9BDC5',
    'cKOMSP1 single': '#B9BDC5',

    'cKOAMA1 x': '#B9BDC5',
    'cKOAMA1 y': '#B9BDC5',
    'cKOAMA1 mean': '#B9BDC5',
    'cKOAMA1 single': '#B9BDC5',

    'cKOGAP45 x': '#B9BDC5',
    'cKOGAP45 y': '#B9BDC5',
    'cKOGAP45 mean': '#B9BDC5',
    'cKOGAP45 single': '#B9BDC5',
    
 
}

colors_dark = {
    'NF54': '#043546',
    'Heparin 50':'#818897',

    '3D7':'#818897',
    '3D7 (viola)': '#818897',

    'KOP230P': '#406a7d',
    'KOPfs25': '#78a3b9',

    'KOEBA140': '#9ECA69',
    'KOEBA181': '#486737',
    'KOEBA175': '#6AB997',
    'KOEBA175+Anti-GYPA':'#04A0AF',
    'KORH1': '#F1AF23',
    'KORH4': '#E8513E',
    'KORh2a': '#ED8626',
    'KORH2a': '#ED8626',


    'Barseq': '#BEBFBC',

    'cKOMSP1 DMSO':'#FFD086',
    'cKOMSP1 Rap':'#FFD086',

    
    'cKOMSP1 DMSO (normal egress)':'#FFD086',
    'cKOMSP1 Rap (clumpy egress)':'#FFD086',

    'Neuraminidase':'#ABDC29',
    
    'Anti-CD55':'#97B6DA',
    'Anti-GYPA':'#91D4CF',
    'R1':'#E459A5',
    'Anti-GYPC':'#35BEB4',
    'Anti-CR1 ab25':'#C6545E',
    'Anti-CR1 ABIN':'#C6545E',

    'Anti-Basigin':'#7E7C9C',
   
    
  
    'cKOGAP45 DMSO': '#81132C',
    'cKOGAP45 Rap': '#81132C',

    
    'cKOAMA1 DMSO':'#CC889D',
    'cKOAMA1 Rap':'#CC889D',

    'NF54 x': '#043546',
    'NF54 y': '#043546',
    'NF54 mean': '#043546',
    'NF54 single': '#043546',

    'cKOMSP1 x': '#FFD086',
    'cKOMSP1 y': '#FFD086',
    'cKOMSP1 mean': '#FFD086',
    'cKOMSP1 single': '#FFD086',

    'cKOAMA1 x': '#CC889D',
    'cKOAMA1 y': '#CC889D',
    'cKOAMA1 mean': '#CC889D',
    'cKOAMA1 single': '#CC889D',

    'cKOGAP45 x': '#81132C',
    'cKOGAP45 y': '#81132C',
    'cKOGAP45 mean': '#81132C',
    'cKOGAP45 single': '#81132C',
}

# Old 
# colors_light = {
#     'NF54': '#829AA3',
#     'NF54 old': '#829AA3',
#     'NF54 new': '#829AA3',
#     'Glut':'#829AA3',
#     'KOEBA140': '#7EB3C1',
#     'KOEBA181': '#9CC3C0',
#     'KOEBA175': '#85A7A7',
#     'KORH1': '#C1C2B1',
#     'KORH4': '#D7E4DD',
#     'KORh2a': '#9ACDB3',
#     'KORH2a': '#9ACDB3',
#     'Barseq': '#BEBFBC',
#     'KOP230P': '#829AA3',
#     'KOPfs25': '#829AA3',
#     '3D7':'#C57380',
#     '3D7 (viola)': '#C57380',
#     'Anti-Basigin':'#ABA9CE',
#     'Anti-CD55':'#97B6DA',
#     'Anti-GYPA':'#B5E2DF',
#     'R1':'#F1AAD1',
#     'Neuraminidase':'#CDEA80',
#     'Anti-GYPC':'#95C3CC',
#     'Anti-CR1 ab25':'#B4E0D4',
#     'Anti-CR1 ABIN':'#B4E0D4',
#     'cKOAMA1 Rap':'#F3C9DA',
#     'cKOAMA1 DMSO':'#829AA3',
#     'KOEBA175+Anti-GYPA':'#4E87A0',
#     'cKOMSP1 DMSO':'#829AA3',
#     'cKOMSP1 Rap':'#F4D0B2',
#     'cKOGAP45 DMSO': '#829AA3',
#     'cKOGAP45 Rap': '#DEAC7F',

# }


#old
# colors_dark = {
#     'NF54': '#043546',
#     'NF54 old': '#043546',
#     'NF54 new': '#043546',
#     'Glut':'#043546',
#     'KOEBA140': '#3F7685',
#     'KOEBA181': '#5F9995',
#     'KOEBA175': '#4B7772',
#     'KORH1': '#78795F',
#     'KORH4': '#6C9A81',
#     'KORh2a': '#30877C',
#     'KORH2a': '#30877C',
#     'Barseq': '#6B777D',
#     'KOP230P': '#122134',
#     'KOPfs25': '#1A175C',
#     '3D7':'#A7144C',
#     '3D7 (viola)': '#A7144C',
#     'Anti-Basigin':'#56529D',
#     'Anti-CD55':'#3A7EB4',
#     'Anti-GYPA':'#6BC4BF',
#     'R1':'#E355A2',
#     'Neuraminidase':'#84BD00',
#     'Anti-GYPC':'#2B8799',
#     'Anti-CR1 ab25':'#3F9A81',
#     'Anti-CR1 ABIN':'#3F9A81',
#     'cKOAMA1 Rap':'#DE5269',
#     'cKOAMA1 DMSO':'#DE5269',
#     'KOEBA175+Anti-GYPA':'#005776',
#     'cKOMSP1 DMSO':'#EBAE7B',
#     'cKOMSP1 Rap':'#EBAE7B',
#     'cKOGAP45 DMSO':'#C87138',
#     'cKOGAP45 Rap':'#C87138',

# }

# only keep conditons we want to plot
df_force = df_force_raw[df_force_raw.index.isin(conditions_to_plot)]
df_freq = df_freq_raw[df_freq_raw.index.isin(conditions_to_plot)]

# reorder conditions to accord with lits
df_force = df_force.reindex(conditions_to_plot)
df_freq = df_freq.reindex(conditions_to_plot)

df_force_plot = df_force.T.stack(dropna=True).reset_index(level=0, name='Detachment force (pN)') # stack forces columnwise
df_force_plot['Condition'] = df_force_plot.index

# %%
import matplotlib.colors as mc
import colorsys

def change_saturation(color, amount=0.5):
    """
    Lightens the given color by multiplying (1-luminosity) by the given amount.
    Input can be matplotlib color string, hex string, or RGB tuple.

    Examples:
    >> lighten_color('g', 0.3)
    >> lighten_color('#F034A3', 0.6)
    >> lighten_color((.3,.55,.1), 0.5)
    """

    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], 1 - amount * (1 - c[1]), c[2])

# %%
# Plot force 

plt.figure()
## size of plot
plt.gcf().set_size_inches(4,9)
#plt.gcf().set_size_inches(12,9)
#plt.gcf().set_size_inches(15,9)
#plt.gcf().set_size_inches(18,9)


plt.gcf().set_dpi(300)

sns.set_theme(#context='notebook', 
            #style='ticks', 
            style='darkgrid', 
            font='arial', 
            font_scale=3.5) 
            #   color_codes=True, 
            #   rc=None)
sns.set_style(rc = {'axes.facecolor': '#F5F5F9'})
#sns.set_style(rc = {'axes.facecolor': '#FBF9F6'})

#Presentation
# sns.set_theme(#context='notebook', 
#             #style='ticks', 
#             style='darkgrid', 
#             font='Candara', 
#             font_scale=3.5) 
#             #   color_codes=True, 
#             #   rc=None)
# sns.set_style(rc = {'axes.facecolor': '#F5F5F9'})
# #sns.set_style(rc = {'axes.facecolor': '#FBF9F6'})

ax = sns.boxplot(
    data=df_force_plot, 
    x=df_force_plot.index, 
    y='Detachment force (pN)', 
    order=conditions_to_plot,
    hue=df_force_plot['Condition'], 
    palette=colors_light, 
    #saturation=.6, 
    dodge=False, 
    showfliers=False, 
    width=0.6,
    medianprops={"color": "red"},
    #medianprops={"color": "red", "linewidth": 3},
    linewidth=1,
)
plt.xticks(rotation=90)


sns.stripplot(
    data=df_force_plot, 
    x=df_force_plot.index, 
    y='Detachment force (pN)', 
    order=conditions_to_plot,
    jitter=True, 
    linewidth=0.4,
    hue=df_force_plot.index,
    palette=colors_dark,
    size=7
)

plt.ylim((0,90))
plt.legend([],[], frameon=False)

# comment out if want the x-labels displayed 
#plt.gca().set_xticklabels([]) 

# this allows the text to be editable in affinitity (it rescales the text)
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig(f'graphs/Fig2_cKOMSP_force.svg', bbox_inches='tight')

#p.get_figure().savefig("S2c_NF54.pdf", dpi=1200, bbox_inches="tight")
# Out:
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot frequency

plt.figure()
## size of plot
plt.gcf().set_size_inches(4,9)
#plt.gcf().set_size_inches(12,9)
#plt.gcf().set_size_inches(15,7)
# plt.gcf().set_size_inches(18,9)
plt.gcf().set_dpi(300)

sns.set_theme(context='notebook', 
              #style='darkgrid', 
              font='arial', 
              font_scale=3.5, 
              color_codes=True, 
              rc=None)
sns.set_style(rc = {'axes.facecolor': '#F5F5F9'})
#sns.set_style(rc = {'axes.facecolor': '#FBF9F6'})

#plot per egress 
plt.bar(
    df_freq.index, 
    df_freq['Mean attached per egress'], 
    yerr=df_freq['SEM of atatched per egress'], 
    capsize=7.5,
    color=[sns.desaturate(colors_light.get(s, 'r'), 0.8) for s in df_freq.index],
    edgecolor=[colors_dark.get(s, 'r') for s in df_freq.index],
    linewidth=2,
    width=0.6,
)


#plot overall percentage 
# plt.bar(
#     df_freq.index, 
#     df_freq['Percentage '], 
#     color=[sns.desaturate(colors_light.get(s, 'r'), 0.5) for s in df_freq.index],
#     edgecolor=[colors_dark.get(s, 'r') for s in df_freq.index],
# )

# plt.ylabel('Overall attachment frequency (%)')
plt.ylabel('Attachment frequency (%)')

plt.xticks(rotation=90)
plt.ylim((0,40))
plt.legend([],[], frameon=False)

# comment out if want the x-labels displayed 
# plt.gca().set_xticklabels([]) 

# this allows the text to be editable in affinitity (it rescales the text)
plt.rcParams['svg.fonttype'] = 'none'
plt.savefig(f'graphs/Fig2_cKOMSP_freq.svg', bbox_inches='tight')
#plt.savefig(f'graphs/tweezer frequency.pdf', bbox_inches='tight')

# %%
from scipy import stats

# returns true if normally distributed with 5% significance level
def adtest(x):
    test = stats.anderson(x)
    return test.statistic < test.significance_level[2]

controls = [
    'NF54', 
    # '3D7',
    # 'KOP230P', 
    # 'KOPfs25',
    #  'Anti-GYPA',
    #  'cKOMSP1 DMSO',
    # 'KOEBA140',
    #'KORH2a'
    # 'cKOGAP45 DMSO',
   # 'cKOAMA1 DMSO',
   #'KOEBA175'
#    'cKOMSP1 single'
#'anti-CR1'
]

control_datapoints = df_force_plot.query('Condition == @controls')['Detachment force (pN)']
NF54_normally_ditributed = adtest(control_datapoints)

print(f'Controls: {", ".join(control_datapoints.index.unique())}')

for strain, dfqq in df_force_plot.query('Condition != @controls').groupby('Condition'):
    b = dfqq['Detachment force (pN)']
    if NF54_normally_ditributed and adtest(b):
        p_val = stats.ttest_ind(control_datapoints, b).pvalue
        print(f'{strain:15s} ttest p-value = {p_val:.4f}, {"significant" if p_val < 0.05 else "not significant"}')

    else:
        print(strain, 'ranksums=', stats.ranksums(control_datapoints, b))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# c:\Users\Emma Jones\OneDrive - University of Cambridge\Documents\My work\cambridge\Year 2\Rayner lab\python\tweezers\tweezer_plots.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a> controls = [
#       <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a>     'NF54',
#      <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     # '3D7',
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=20'>21</a> #'anti-CR1'
#      <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a> ]
#      <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a> control_datapoints = df_force_plot.query('Condition == @controls')['Detachment force (pN)']
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=24'>25</a> NF54_normally_ditributed = adtest(control_datapoints)
#      <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=26'>27</a> print(f'Controls: {", ".join(control_datapoints.index.unique())}')
#      <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=28'>29</a> for strain, dfqq in df_force_plot.query('Condition != @controls').groupby('Condition'):
#
# c:\Users\Emma Jones\OneDrive - University of Cambridge\Documents\My work\cambridge\Year 2\Rayner lab\python\tweezers\tweezer_plots.ipynb Cell 8 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> def adtest(x):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     test = stats.anderson(x)
#       <a href='vscode-notebook-cell:/c%3A/Users/Emma%20Jones/OneDrive%20-%20University%20of%20Cambridge/Documents/My%20work/cambridge/Year%202/Rayner%20lab/python/tweezers/tweezer_plots.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     return test.statistic < test.significance_level[2]
#
# File c:\Users\Emma Jones\.conda\envs\py311\Lib\site-packages\scipy\stats\_morestats.py:1953, in anderson(x, dist)
#    1951     logsf = distributions.norm.logsf(w)
#    1952     sig = array([15, 10, 5, 2.5, 1])
# -> 1953     critical = around(_Avals_norm / (1.0 + 4.0/N - 25.0/N/N), 3)
#    1954 elif dist == 'expon':
#    1955     w = y / xbar
#
# ZeroDivisionError: float division by zero
